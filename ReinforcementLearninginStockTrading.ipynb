# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal077/Financial-Engineering/blob/main/ReinforcementLearninginStockTrading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# !pip install yfinance --upgrade --no-cache-dir
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
from collections import deque
import random
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_eager_execution()
# Out:
# Requirement already up-to-date: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.59)
# Requirement already satisfied, skipping upgrade: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.6.3)
# Requirement already satisfied, skipping upgrade: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied, skipping upgrade: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied, skipping upgrade: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)

# %%
yf.pdr_override()
df_full = pdr.get_data_yahoo("INFY", start="2018-01-01").reset_index()
df_full.to_csv('INFY.csv',index=False)
df_full.head()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0 2018-01-02  8.135  8.195  8.115  8.145   7.429263  12298200
# 1 2018-01-03  8.120  8.135  8.050  8.075   7.365414  10250800
# 2 2018-01-04  8.100  8.100  8.010  8.025   7.319807  16272000
# 3 2018-01-05  8.085  8.190  8.075  8.175   7.456626   9813600
# 4 2018-01-08  8.190  8.260  8.170  8.240   7.515914  11198200

# %%
df= df_full.copy()
name = 'Q-learning agent'
class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []
        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999
        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())
    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, window_size = window_size, trend = close, 
              skip = skip, batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1719: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# epoch: 10, total rewards: 5.840002.3, cost: 0.009371, total money: 10005.840002
# epoch: 20, total rewards: 3.564999.3, cost: 0.007659, total money: 10003.564999
# epoch: 30, total rewards: 4.579999.3, cost: 0.007132, total money: 10004.579999
# epoch: 40, total rewards: 3.699999.3, cost: 0.006885, total money: 10003.699999
# epoch: 50, total rewards: 5.685000.3, cost: 0.007829, total money: 10005.685000
# epoch: 60, total rewards: 5.785000.3, cost: 0.008844, total money: 10005.785000
# epoch: 70, total rewards: 6.679999.3, cost: 0.008975, total money: 10006.679999
# epoch: 80, total rewards: 3.215000.3, cost: 0.007134, total money: 10003.215000
# epoch: 90, total rewards: 2.205000.3, cost: 0.006900, total money: 10002.205000
# epoch: 100, total rewards: 3.764999.3, cost: 0.006662, total money: 10003.764999
# epoch: 110, total rewards: 5.249999.3, cost: 0.006459, total money: 10005.249999
# epoch: 120, total rewards: 7.304999.3, cost: 0.006276, total money: 10007.304999
# epoch: 130, total rewards: 5.679999.3, cost: 0.006131, total money: 10005.679999
# epoch: 140, total rewards: 6.824999.3, cost: 0.005971, total money: 10006.824999
# epoch: 150, total rewards: 6.434999.3, cost: 0.005831, total money: 10006.434999
# epoch: 160, total rewards: 9.279998.3, cost: 0.005158, total money: 10009.279998
# epoch: 170, total rewards: 5.584998.3, cost: 0.006217, total money: 10005.584998
# epoch: 180, total rewards: 7.459999.3, cost: 0.005435, total money: 10007.459999
# epoch: 190, total rewards: 10.524999.3, cost: 0.005302, total money: 10010.524999
# epoch: 200, total rewards: 10.354999.3, cost: 0.005192, total money: 10010.354999

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 8.145000, total balance 9991.855000
# day 1: buy 1 unit at price 8.075000, total balance 9983.780000
# day 2: buy 1 unit at price 8.025000, total balance 9975.755000
# day 4: buy 1 unit at price 8.240000, total balance 9967.515000
# day 5, sell 1 unit at price 8.370000, investment 2.762431 %, total balance 9975.885000,
# day 6, sell 1 unit at price 8.495000, investment 5.201238 %, total balance 9984.380000,
# day 7, sell 1 unit at price 8.635000, investment 7.601246 %, total balance 9993.015000,
# day 8, sell 1 unit at price 8.405000, investment 2.002427 %, total balance 10001.420000,
# day 12: buy 1 unit at price 8.995000, total balance 9992.425000
# day 15: buy 1 unit at price 9.230000, total balance 9983.195000
# day 16: buy 1 unit at price 9.225000, total balance 9973.970000
# day 20: buy 1 unit at price 9.005000, total balance 9964.965000
# day 22: buy 1 unit at price 8.875000, total balance 9956.090000
# day 23, sell 1 unit at price 8.685000, investment -3.446359 %, total balance 9964.775000,
# day 25, sell 1 unit at price 8.740000, investment -5.308776 %, total balance 9973.515000,
# day 26, sell 1 unit at price 8.555000, investment -7.262873 %, total balance 9982.070000,
# day 27: buy 1 unit at price 8.680000, total balance 9973.390000
# day 28, sell 1 unit at price 8.810000, investment -2.165464 %, total balance 9982.200000,
# day 29, sell 1 unit at price 8.730000, investment -1.633803 %, total balance 9990.930000,
# day 30, sell 1 unit at price 8.785000, investment 1.209677 %, total balance 9999.715000,
# day 31: buy 1 unit at price 8.805000, total balance 9990.910000
# day 32, sell 1 unit at price 8.795000, investment -0.113572 %, total balance 9999.705000,
# day 35: buy 1 unit at price 8.900000, total balance 9990.805000
# day 36, sell 1 unit at price 8.980000, investment 0.898876 %, total balance 9999.785000,
# day 49: buy 1 unit at price 9.190000, total balance 9990.595000
# day 50, sell 1 unit at price 9.150000, investment -0.435256 %, total balance 9999.745000,
# day 52: buy 1 unit at price 8.990000, total balance 9990.755000
# day 54, sell 1 unit at price 9.020000, investment 0.333704 %, total balance 9999.775000,
# day 63: buy 1 unit at price 8.915000, total balance 9990.860000
# day 64: buy 1 unit at price 8.935000, total balance 9981.925000
# day 65, sell 1 unit at price 8.745000, investment -1.906898 %, total balance 9990.670000,
# day 66, sell 1 unit at price 8.630000, investment -3.413542 %, total balance 9999.300000,
# day 82: buy 1 unit at price 8.820000, total balance 9990.480000
# day 84: buy 1 unit at price 8.840000, total balance 9981.640000
# day 85, sell 1 unit at price 8.830000, investment 0.113379 %, total balance 9990.470000,
# day 86: buy 1 unit at price 8.720000, total balance 9981.750000
# day 90, sell 1 unit at price 8.780000, investment -0.678733 %, total balance 9990.530000,
# day 92, sell 1 unit at price 8.760000, investment 0.458716 %, total balance 9999.290000,
# day 97: buy 1 unit at price 8.760000, total balance 9990.530000
# day 98, sell 1 unit at price 8.905000, investment 1.655251 %, total balance 9999.435000,
# day 101: buy 1 unit at price 9.000000, total balance 9990.435000
# day 104, sell 1 unit at price 9.145000, investment 1.611111 %, total balance 9999.580000,
# day 108: buy 1 unit at price 9.285000, total balance 9990.295000
# day 109: buy 1 unit at price 9.365000, total balance 9980.930000
# day 110, sell 1 unit at price 9.375000, investment 0.969305 %, total balance 9990.305000,
# day 112, sell 1 unit at price 9.410000, investment 0.480513 %, total balance 9999.715000,
# day 115: buy 1 unit at price 9.220000, total balance 9990.495000
# day 116, sell 1 unit at price 9.100000, investment -1.301518 %, total balance 9999.595000,
# day 117: buy 1 unit at price 9.080000, total balance 9990.515000
# day 118, sell 1 unit at price 9.115000, investment 0.385463 %, total balance 9999.630000,
# day 120: buy 1 unit at price 9.320000, total balance 9990.310000
# day 121, sell 1 unit at price 9.360000, investment 0.429185 %, total balance 9999.670000,
# day 124: buy 1 unit at price 9.715000, total balance 9989.955000
# day 125, sell 1 unit at price 9.805000, investment 0.926402 %, total balance 9999.760000,
# day 127: buy 1 unit at price 9.670000, total balance 9990.090000
# day 128, sell 1 unit at price 9.575000, investment -0.982420 %, total balance 9999.665000,
# day 132: buy 1 unit at price 10.005000, total balance 9989.660000
# day 133, sell 1 unit at price 9.710000, investment -2.948526 %, total balance 9999.370000,
# day 141: buy 1 unit at price 10.290000, total balance 9989.080000
# day 142: buy 1 unit at price 10.270000, total balance 9978.810000
# day 143, sell 1 unit at price 10.170000, investment -1.166181 %, total balance 9988.980000,
# day 147: buy 1 unit at price 10.190000, total balance 9978.790000
# day 148, sell 1 unit at price 10.270000, investment 0.000000 %, total balance 9989.060000,
# day 149, sell 1 unit at price 10.295000, investment 1.030422 %, total balance 9999.355000,
# day 152: buy 1 unit at price 10.450000, total balance 9988.905000
# day 153, sell 1 unit at price 10.400000, investment -0.478469 %, total balance 9999.305000,
# day 156: buy 1 unit at price 10.435000, total balance 9988.870000
# day 158: buy 1 unit at price 10.540000, total balance 9978.330000
# day 159, sell 1 unit at price 10.250000, investment -1.772880 %, total balance 9988.580000,
# day 163: buy 1 unit at price 10.150000, total balance 9978.430000
# day 164, sell 1 unit at price 10.270000, investment -2.561670 %, total balance 9988.700000,
# day 165, sell 1 unit at price 10.325000, investment 1.724138 %, total balance 9999.025000,
# day 167: buy 1 unit at price 10.230000, total balance 9988.795000
# day 168: buy 1 unit at price 10.385000, total balance 9978.410000
# day 169, sell 1 unit at price 10.380000, investment 1.466276 %, total balance 9988.790000,
# day 170, sell 1 unit at price 10.355000, investment -0.288878 %, total balance 9999.145000,
# day 171: buy 1 unit at price 10.400000, total balance 9988.745000
# day 172, sell 1 unit at price 10.425000, investment 0.240385 %, total balance 9999.170000,
# day 173: buy 1 unit at price 10.350000, total balance 9988.820000
# day 174: buy 1 unit at price 10.485000, total balance 9978.335000
# day 175, sell 1 unit at price 10.550000, investment 1.932367 %, total balance 9988.885000,
# day 176, sell 1 unit at price 10.610000, investment 1.192179 %, total balance 9999.495000,
# day 186: buy 1 unit at price 10.100000, total balance 9989.395000
# day 187: buy 1 unit at price 10.170000, total balance 9979.225000
# day 189, sell 1 unit at price 10.270000, investment 1.683168 %, total balance 9989.495000,
# day 190, sell 1 unit at price 10.040000, investment -1.278269 %, total balance 9999.535000,
# day 191: buy 1 unit at price 10.000000, total balance 9989.535000
# day 193, sell 1 unit at price 10.030000, investment 0.300000 %, total balance 9999.565000,
# day 194: buy 1 unit at price 10.020000, total balance 9989.545000
# day 195, sell 1 unit at price 9.740000, investment -2.794411 %, total balance 9999.285000,
# day 201: buy 1 unit at price 9.540000, total balance 9989.745000
# day 203, sell 1 unit at price 9.480000, investment -0.628931 %, total balance 9999.225000,
# day 205: buy 1 unit at price 9.060000, total balance 9990.165000
# day 207, sell 1 unit at price 9.020000, investment -0.441501 %, total balance 9999.185000,
# day 209: buy 1 unit at price 9.190000, total balance 9989.995000
# day 210, sell 1 unit at price 9.470000, investment 3.046790 %, total balance 9999.465000,
# day 216: buy 1 unit at price 9.510000, total balance 9989.955000
# day 217, sell 1 unit at price 9.490000, investment -0.210305 %, total balance 9999.445000,
# day 220: buy 1 unit at price 9.250000, total balance 9990.195000
# day 223, sell 1 unit at price 9.290000, investment 0.432432 %, total balance 9999.485000,
# day 232: buy 1 unit at price 9.900000, total balance 9989.585000
# day 233, sell 1 unit at price 9.850000, investment -0.505051 %, total balance 9999.435000,
# day 240: buy 1 unit at price 9.890000, total balance 9989.545000
# day 242, sell 1 unit at price 9.540000, investment -3.538928 %, total balance 9999.085000,
# day 247: buy 1 unit at price 9.380000, total balance 9989.705000
# day 248, sell 1 unit at price 9.450000, investment 0.746269 %, total balance 9999.155000,
# day 257: buy 1 unit at price 9.880000, total balance 9989.275000
# day 258, sell 1 unit at price 10.410000, investment 5.364372 %, total balance 9999.685000,
# day 260: buy 1 unit at price 10.490000, total balance 9989.195000
# day 261, sell 1 unit at price 10.610000, investment 1.143947 %, total balance 9999.805000,
# day 264: buy 1 unit at price 10.530000, total balance 9989.275000
# day 266, sell 1 unit at price 10.430000, investment -0.949668 %, total balance 9999.705000,
# day 269: buy 1 unit at price 10.480000, total balance 9989.225000
# day 272, sell 1 unit at price 10.900000, investment 4.007634 %, total balance 10000.125000,
# day 275: buy 1 unit at price 10.900000, total balance 9989.225000
# day 276: buy 1 unit at price 10.850000, total balance 9978.375000
# day 277, sell 1 unit at price 10.860000, investment -0.366972 %, total balance 9989.235000,
# day 278: buy 1 unit at price 10.820000, total balance 9978.415000
# day 282, sell 1 unit at price 10.760000, investment -0.829493 %, total balance 9989.175000,
# day 285, sell 1 unit at price 10.550000, investment -2.495379 %, total balance 9999.725000,
# day 293: buy 1 unit at price 10.770000, total balance 9988.955000
# day 295, sell 1 unit at price 10.490000, investment -2.599814 %, total balance 9999.445000,
# day 297: buy 1 unit at price 10.550000, total balance 9988.895000
# day 299, sell 1 unit at price 10.550000, investment 0.000000 %, total balance 9999.445000,
# day 304: buy 1 unit at price 10.940000, total balance 9988.505000
# day 305, sell 1 unit at price 11.060000, investment 1.096892 %, total balance 9999.565000,
# day 306: buy 1 unit at price 10.880000, total balance 9988.685000
# day 307: buy 1 unit at price 10.820000, total balance 9977.865000
# day 308: buy 1 unit at price 10.820000, total balance 9967.045000
# day 309: buy 1 unit at price 10.730000, total balance 9956.315000
# day 311, sell 1 unit at price 10.930000, investment 0.459559 %, total balance 9967.245000,
# day 312, sell 1 unit at price 11.090000, investment 2.495379 %, total balance 9978.335000,
# day 313, sell 1 unit at price 11.180000, investment 3.327172 %, total balance 9989.515000,
# day 315, sell 1 unit at price 11.070000, investment 3.168686 %, total balance 10000.585000,
# day 319: buy 1 unit at price 11.080000, total balance 9989.505000
# day 320: buy 1 unit at price 10.970000, total balance 9978.535000
# day 321, sell 1 unit at price 10.550000, investment -4.783394 %, total balance 9989.085000,
# day 323, sell 1 unit at price 10.370000, investment -5.469462 %, total balance 9999.455000,
# day 333: buy 1 unit at price 10.770000, total balance 9988.685000
# day 334, sell 1 unit at price 10.570000, investment -1.857010 %, total balance 9999.255000,
# day 335: buy 1 unit at price 10.330000, total balance 9988.925000
# day 337, sell 1 unit at price 10.340000, investment 0.096805 %, total balance 9999.265000,
# day 346: buy 1 unit at price 10.200000, total balance 9989.065000
# day 348: buy 1 unit at price 10.220000, total balance 9978.845000
# day 349: buy 1 unit at price 10.160000, total balance 9968.685000
# day 351, sell 1 unit at price 10.300000, investment 0.980392 %, total balance 9978.985000,
# day 352, sell 1 unit at price 10.270000, investment 0.489237 %, total balance 9989.255000,
# day 354: buy 1 unit at price 10.470000, total balance 9978.785000
# day 355, sell 1 unit at price 10.450000, investment 2.854331 %, total balance 9989.235000,
# day 357, sell 1 unit at price 10.440000, investment -0.286533 %, total balance 9999.675000,
# day 360: buy 1 unit at price 10.780000, total balance 9988.895000
# day 361, sell 1 unit at price 10.840000, investment 0.556586 %, total balance 9999.735000,
# day 364: buy 1 unit at price 10.600000, total balance 9989.135000
# day 366: buy 1 unit at price 10.750000, total balance 9978.385000
# day 367, sell 1 unit at price 10.600000, investment 0.000000 %, total balance 9988.985000,
# day 369, sell 1 unit at price 10.720000, investment -0.279070 %, total balance 9999.705000,
# day 377: buy 1 unit at price 10.740000, total balance 9988.965000
# day 378, sell 1 unit at price 10.690000, investment -0.465549 %, total balance 9999.655000,
# day 386: buy 1 unit at price 11.490000, total balance 9988.165000
# day 387: buy 1 unit at price 11.550000, total balance 9976.615000
# day 391, sell 1 unit at price 11.460000, investment -0.261097 %, total balance 9988.075000,
# day 393, sell 1 unit at price 11.480000, investment -0.606061 %, total balance 9999.555000,
# day 400: buy 1 unit at price 11.000000, total balance 9988.555000
# day 401, sell 1 unit at price 11.160000, investment 1.454545 %, total balance 9999.715000,
# day 404: buy 1 unit at price 11.100000, total balance 9988.615000
# day 406, sell 1 unit at price 10.790000, investment -2.792793 %, total balance 9999.405000,
# day 411: buy 1 unit at price 11.300000, total balance 9988.105000
# day 412, sell 1 unit at price 11.210000, investment -0.796460 %, total balance 9999.315000,
# day 413: buy 1 unit at price 11.110000, total balance 9988.205000
# day 415, sell 1 unit at price 11.150000, investment 0.360036 %, total balance 9999.355000,
# day 418: buy 1 unit at price 11.490000, total balance 9987.865000
# day 419, sell 1 unit at price 11.280000, investment -1.827676 %, total balance 9999.145000,
# day 423: buy 1 unit at price 11.640000, total balance 9987.505000
# day 426: buy 1 unit at price 11.680000, total balance 9975.825000
# day 427: buy 1 unit at price 11.770000, total balance 9964.055000
# day 428: buy 1 unit at price 11.760000, total balance 9952.295000
# day 429, sell 1 unit at price 11.670000, investment 0.257732 %, total balance 9963.965000,
# day 431, sell 1 unit at price 11.600000, investment -0.684932 %, total balance 9975.565000,
# day 436, sell 1 unit at price 11.130000, investment -5.437553 %, total balance 9986.695000,
# day 437, sell 1 unit at price 11.210000, investment -4.676871 %, total balance 9997.905000,
# day 438: buy 1 unit at price 11.370000, total balance 9986.535000
# day 439, sell 1 unit at price 11.040000, investment -2.902375 %, total balance 9997.575000,
# day 447: buy 1 unit at price 10.970000, total balance 9986.605000
# day 448: buy 1 unit at price 10.620000, total balance 9975.985000
# day 451, sell 1 unit at price 10.590000, investment -3.463993 %, total balance 9986.575000,
# day 453, sell 1 unit at price 9.290000, investment -12.523540 %, total balance 9995.865000,
# day 467: buy 1 unit at price 9.680000, total balance 9986.185000
# day 468: buy 1 unit at price 9.790000, total balance 9976.395000
# day 469, sell 1 unit at price 9.750000, investment 0.723140 %, total balance 9986.145000,
# day 470, sell 1 unit at price 9.710000, investment -0.817160 %, total balance 9995.855000,
# day 478: buy 1 unit at price 9.870000, total balance 9985.985000
# day 479, sell 1 unit at price 9.650000, investment -2.228977 %, total balance 9995.635000,
# day 491: buy 1 unit at price 10.080000, total balance 9985.555000
# day 492, sell 1 unit at price 10.130000, investment 0.496032 %, total balance 9995.685000,
# day 502: buy 1 unit at price 10.320000, total balance 9985.365000
# day 503, sell 1 unit at price 10.290000, investment -0.290698 %, total balance 9995.655000,
# day 504: buy 1 unit at price 10.310000, total balance 9985.345000
# day 505, sell 1 unit at price 10.210000, investment -0.969932 %, total balance 9995.555000,
# day 506: buy 1 unit at price 10.100000, total balance 9985.455000
# day 507, sell 1 unit at price 10.090000, investment -0.099010 %, total balance 9995.545000,
# day 512: buy 1 unit at price 10.850000, total balance 9984.695000
# day 515: buy 1 unit at price 10.850000, total balance 9973.845000
# day 517, sell 1 unit at price 11.060000, investment 1.935484 %, total balance 9984.905000,
# day 518, sell 1 unit at price 11.030000, investment 1.658986 %, total balance 9995.935000,
# day 521: buy 1 unit at price 11.060000, total balance 9984.875000
# day 523, sell 1 unit at price 10.960000, investment -0.904159 %, total balance 9995.835000,
# day 526: buy 1 unit at price 11.040000, total balance 9984.795000
# day 527, sell 1 unit at price 10.960000, investment -0.724638 %, total balance 9995.755000,
# day 538: buy 1 unit at price 11.220000, total balance 9984.535000
# day 539, sell 1 unit at price 11.020000, investment -1.782531 %, total balance 9995.555000,
# day 542: buy 1 unit at price 10.070000, total balance 9985.485000
# day 544, sell 1 unit at price 10.210000, investment 1.390268 %, total balance 9995.695000,
# day 552: buy 1 unit at price 8.380000, total balance 9987.315000
# day 553, sell 1 unit at price 7.370000, investment -12.052506 %, total balance 9994.685000,
# day 556: buy 1 unit at price 7.130000, total balance 9987.555000
# day 561, sell 1 unit at price 9.100000, investment 27.629734 %, total balance 9996.655000,
# day 565: buy 1 unit at price 7.780000, total balance 9988.875000
# day 567: buy 1 unit at price 7.560000, total balance 9981.315000
# day 569, sell 1 unit at price 8.380000, investment 7.712082 %, total balance 9989.695000,
# day 570, sell 1 unit at price 8.480000, investment 12.169312 %, total balance 9998.175000,
# day 576: buy 1 unit at price 8.580000, total balance 9989.595000
# day 578: buy 1 unit at price 8.250000, total balance 9981.345000
# day 579, sell 1 unit at price 8.550000, investment -0.349650 %, total balance 9989.895000,
# day 585, sell 1 unit at price 9.230000, investment 11.878788 %, total balance 9999.125000,
# day 601: buy 1 unit at price 9.050000, total balance 9990.075000
# day 602, sell 1 unit at price 9.070000, investment 0.220994 %, total balance 9999.145000,
# day 606: buy 1 unit at price 9.260000, total balance 9989.885000
# day 608: buy 1 unit at price 9.270000, total balance 9980.615000
# day 609, sell 1 unit at price 9.270000, investment 0.107991 %, total balance 9989.885000,
# day 610: buy 1 unit at price 9.380000, total balance 9980.505000
# day 611, sell 1 unit at price 9.560000, investment 3.128371 %, total balance 9990.065000,
# day 612: buy 1 unit at price 9.330000, total balance 9980.735000
# day 614: buy 1 unit at price 8.860000, total balance 9971.875000
# day 617, sell 1 unit at price 9.120000, investment -2.771855 %, total balance 9980.995000,
# day 619: buy 1 unit at price 9.220000, total balance 9971.775000
# day 620, sell 1 unit at price 9.160000, investment -1.822079 %, total balance 9980.935000,
# day 621: buy 1 unit at price 9.150000, total balance 9971.785000
# day 622, sell 1 unit at price 9.420000, investment 6.320542 %, total balance 9981.205000,
# day 624: buy 1 unit at price 9.290000, total balance 9971.915000
# day 626, sell 1 unit at price 9.570000, investment 3.796095 %, total balance 9981.485000,
# day 628: buy 1 unit at price 9.680000, total balance 9971.805000
# day 629, sell 1 unit at price 9.920000, investment 8.415301 %, total balance 9981.725000,
# day 630, sell 1 unit at price 10.110000, investment 8.826695 %, total balance 9991.835000,
# day 632, sell 1 unit at price 10.340000, investment 6.818182 %, total balance 10002.175000,
# day 635: buy 1 unit at price 10.470000, total balance 9991.705000
# day 638, sell 1 unit at price 12.230000, investment 16.809933 %, total balance 10003.935000,
# day 639: buy 1 unit at price 12.270000, total balance 9991.665000
# day 640, sell 1 unit at price 12.580000, investment 2.526487 %, total balance 10004.245000,
# day 643: buy 1 unit at price 12.240000, total balance 9992.005000
# day 648, sell 1 unit at price 12.950000, investment 5.800654 %, total balance 10004.955000,
# day 655: buy 1 unit at price 12.590000, total balance 9992.365000
# day 656, sell 1 unit at price 12.630000, investment 0.317712 %, total balance 10004.995000,
# day 658: buy 1 unit at price 12.780000, total balance 9992.215000
# day 664, sell 1 unit at price 12.600000, investment -1.408451 %, total balance 10004.815000,
# day 671: buy 1 unit at price 12.670000, total balance 9992.145000
# day 674, sell 1 unit at price 12.440000, investment -1.815312 %, total balance 10004.585000,
# day 678: buy 1 unit at price 12.760000, total balance 9991.825000
# day 679, sell 1 unit at price 13.240000, investment 3.761755 %, total balance 10005.065000,
# day 685: buy 1 unit at price 13.840000, total balance 9991.225000
# day 686, sell 1 unit at price 13.590000, investment -1.806358 %, total balance 10004.815000,
# day 687: buy 1 unit at price 13.050000, total balance 9991.765000
# day 689: buy 1 unit at price 13.630000, total balance 9978.135000
# day 690, sell 1 unit at price 13.560000, investment 3.908046 %, total balance 9991.695000,
# day 693, sell 1 unit at price 13.670000, investment 0.293470 %, total balance 10005.365000,
# day 698: buy 1 unit at price 15.200000, total balance 9990.165000
# day 699, sell 1 unit at price 15.550000, investment 2.302632 %, total balance 10005.715000,
# day 707: buy 1 unit at price 15.350000, total balance 9990.365000
# day 709, sell 1 unit at price 14.920000, investment -2.801303 %, total balance 10005.285000,
# day 714: buy 1 unit at price 14.250000, total balance 9991.035000
# day 715, sell 1 unit at price 14.300000, investment 0.350877 %, total balance 10005.335000,
# day 716: buy 1 unit at price 14.680000, total balance 9990.655000
# day 717, sell 1 unit at price 15.010000, investment 2.247956 %, total balance 10005.665000,
# day 718: buy 1 unit at price 14.930000, total balance 9990.735000
# day 719, sell 1 unit at price 14.830000, investment -0.669792 %, total balance 10005.565000,
# day 727: buy 1 unit at price 14.830000, total balance 9990.735000
# day 730, sell 1 unit at price 15.530000, investment 4.720162 %, total balance 10006.265000,
# day 734: buy 1 unit at price 15.380000, total balance 9990.885000
# day 735, sell 1 unit at price 15.410000, investment 0.195059 %, total balance 10006.295000,
# day 739: buy 1 unit at price 16.010000, total balance 9990.285000
# day 740, sell 1 unit at price 15.530000, investment -2.998126 %, total balance 10005.815000,
# day 743: buy 1 unit at price 15.660000, total balance 9990.155000
# day 747, sell 1 unit at price 16.219999, investment 3.575983 %, total balance 10006.374999,
# day 755: buy 1 unit at price 16.950001, total balance 9989.424998
# day 762, sell 1 unit at price 18.600000, investment 9.734507 %, total balance 10008.024998,
# day 763: buy 1 unit at price 18.430000, total balance 9989.594998
# day 766, sell 1 unit at price 18.120001, investment -1.682035 %, total balance 10007.714999,
# day 767: buy 1 unit at price 18.400000, total balance 9989.314999
# day 768, sell 1 unit at price 18.200001, investment -1.086951 %, total balance 10007.515000,
# day 777: buy 1 unit at price 17.650000, total balance 9989.865000
# day 778: buy 1 unit at price 17.590000, total balance 9972.275000
# day 779, sell 1 unit at price 17.629999, investment -0.113320 %, total balance 9989.904999,
# day 785, sell 1 unit at price 17.750000, investment 0.909608 %, total balance 10007.654999,
# day 786: buy 1 unit at price 17.600000, total balance 9990.054999
# day 788: buy 1 unit at price 17.940001, total balance 9972.114998
# day 789, sell 1 unit at price 17.610001, investment 0.056824 %, total balance 9989.724999,
# day 790: buy 1 unit at price 17.379999, total balance 9972.345000
# day 796, sell 1 unit at price 18.459999, investment 2.898539 %, total balance 9990.804999,
# day 797: buy 1 unit at price 18.170000, total balance 9972.634999
# day 799, sell 1 unit at price 17.980000, investment 3.452250 %, total balance 9990.614999,
# day 802, sell 1 unit at price 19.080000, investment 5.008255 %, total balance 10009.694999,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()
